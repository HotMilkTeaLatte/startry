# %%
# %cd /content/drive/MyDrive/프로젝트 폴더/data/data_list
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-4f1326e428de>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/프로젝트 폴더/data/data_list')
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/magic.py", line 187, in <lambda>
# ...

# %%
import requests
import pandas as pd
# api 키설정
apikey = '785a726b62746a653536736a6d5045'


# 요청 link 리스트
link_list = [
            #  ('Vwsm_TrdhlWrcPopltnQq', '상권배후지-직장인구'),  O
            #  ('VwsmTrdarWrcPopltnQq', '상권-직장인구'), O
            #  ('VwsmTrdhlStorQq', '상권배후지-점포'),  O
            #  ('VwsmTrdarStorQq', '상권-점포'),          
            #  ('VwsmTrdhlNcmCnsmpQq', '상권배후지-소득소비'),  O
            #  ('VwsmTrdhlFlpopQq', '상권배후지-생활인구'), O
            #  ('VwsmTrdarFlpopQq', '상권-생활인구'), O
            #  ('VwsmTrdhlRepopQq', '상권배후지-상주인구'), O
            #  ('VwsmTrdarRepopQq', '상권-상주인구'), O
            #  ('VwsmTrdhlFcltyQq', '상권배후지-집객시설'), O
            #  ('VwsmTrdarFcltyQq', '상권-집객시설'), O
             ('VwsmTrdhlSelngQq', '상권배후지-추정매출'),  
            #  ('VwsmTrdarSelngQq', '상권-추정매출'),        
            #  ('VwsmTrdarIxQq', '상권-상권변화지표'),
            #  ('SPOP_FORN_TEMP_RESD_DONG', '행정동_단위_서울_생활인구(단기체류_외국인)'),
            #  ('ppsLongResd', '행정동_단위_서울_생활인구(장기체류_외국인)')
            #  ('TbgisTrdarRelm', '상권영역')
             ]

for link,name in link_list:
  # 데이터 시작,끝설정
  startnum = 1
  endnum = 1
  url = f'http://openapi.seoul.go.kr:8088/{apikey}/json/{link}/{startnum}/{endnum}/'
  # json 형태로 전달
  json1 = requests.get(url)
  # json 요청 응답 코드
  json1.raise_for_status()
  # 한글 깨짐 인코딩 변경
  json1.encoding = 'utf-8'

  # json 파일 불러오기
  json_file = json1.json()

  # json 데이터 총 갯수
  data_len = json_file[link]['list_total_count']
  print(data_len)

  # 기본 데이터프레임
  data = pd.DataFrame(json_file[link]['row'])

  # data 요청, dataframe 저장
  for i in range(data_len//1000+1):
    startnum = 1000*i+2
    endnum = 1000*i+1001
    url = f'http://openapi.seoul.go.kr:8088/{apikey}/json/{link}/{startnum}/{endnum}/'
    json1 = requests.get(url)
    json1.raise_for_status()
    json1.encoding = 'UTF-8'
    json_file = json1.json()
    # print(json_file[link]['RESULT'])
    append_data = pd.DataFrame(json_file[link]['row'])
    append_data.reset_index(drop=True)
    data = pd.concat([data,append_data])

  # dataframe 정렬 후 csv파일 저장 
  data.sort_values(by=[data.columns[0], data.columns[1]])
  data.to_csv(f"{name}.csv", encoding='utf-8-sig',index=False)
  print(f"{name}.csv, 행 {len(data)}개 저장완료")
# Out:
# <Response [200]>
# 1250350

# %%
# 상권-소득소비 - 데이터가 연도별, 분기별로 따로 저장되어 있음

import requests
import pandas as pd
# api 키설정
apikey = '785a726b62746a653536736a6d5045'


# 요청 link 리스트
link_list = [('trdarNcmCnsmp', '상권-소득소비')]
year = [2017,2018,2019,2020,2021,2022]
quarter = [1,2,3,4]
for link,name in link_list:
  for y in year:
    for q in quarter:
      # 데이터 시작,끝설정
      startnum = 1
      endnum = 1
      url = f'http://openapi.seoul.go.kr:8088/{apikey}/json/{link}/{startnum}/{endnum}/{y}/{q}'
      # json 형태로 전달
      json1 = requests.get(url)
      print(json1)

      # 한글 깨짐 인코딩 변경
      json1.raise_for_status()
      json1.encoding = 'utf-8'

      # json 파일 불러오기
      json_file = json1.json()

      # json 데이터 개수
      data_len = json_file[link]['list_total_count']
      print(data_len)
      # 기본 데이터프레임
      data = pd.DataFrame(json_file[link]['row'])

      # data 추출, dataframe 저장
      for i in range(data_len//1000+1):
        startnum = 1000*i+2
        endnum = 1000*i+1001
        url = f'http://openapi.seoul.go.kr:8088/{apikey}/json/{link}/{startnum}/{endnum}/{y}/{q}'
        json1 = requests.get(url)
        json1.raise_for_status()
        json1.encoding = 'UTF-8'
        json_file = json1.json()
        # print(json_file[link]['RESULT'])
        append_data = pd.DataFrame(json_file[link]['row'])
        append_data.reset_index(drop=True)
        data = pd.concat([data,append_data])

  # dataframe 정렬 후 csv파일 저장 
  data.sort_values(by=[data.columns[0], data.columns[1]])
  data.to_csv(f"{name}.csv", encoding='utf-8-sig',index=False)
  print(f"{name}.csv, 행 {len(data)}개 저장완료")
